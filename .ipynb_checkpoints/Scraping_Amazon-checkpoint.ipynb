# %%
from __future__ import print_function, division
# %autosave 120

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
# Out:
# Autosaving every 120 seconds

# %%
import requests
from bs4 import BeautifulSoup

import re
import string

import time

# %% [markdown]
# # Load 'IMDB' df

# %%
final_imdb = pickle.load(open("final_imdb_int.p", "rb"))

# %%
final_imdb.shape
# Out:
# (606, 10)

# %%
final_imdb.sample(5)
# Out:
#         imdbid                 gross  \
# 78   tt0104691     $75,505,856 (USA)
# 81   tt0417741  $301,959,197 (USA) (
# 185  tt0243155   $71,500,556 (USA) (
# 13   tt0137523   $37,030,102 (USA) (
# 553  tt0117002      $5,600,000 (USA)
#
#                                                 amazon    amazonid  metascore  \
# 78   <a href="http://www.amazon.com/exec/obidos/ASI...  0553213296         76
# 81   <a href="http://www.amazon.com/exec/obidos/ASI...  074758110X         78
# 185  <a href="http://www.amazon.com/exec/obidos/ASI...  0752261924         66
# 13   <a href="http://www.amazon.com/exec/obidos/ASI...  0393039765         66
# 553  <a href="http://www.amazon.com/exec/obidos/ASI...  0385249683         44
#
#       ranks                                   title  \
# 78     136.                The Last of the Mohicans
# 81     140.  Harry Potter and the Half-Blood Prince
# 185    329.                   Bridget Jones's Diary
# 13      28.                              Fight Club
# 553  1,760.                             Mary Reilly
#
#                                 links release  box_office
# 78   /title/tt0104691/?ref_=adv_li_tt  (1992)    75505856
# 81   /title/tt0417741/?ref_=adv_li_tt  (2009)   301959197
# 185  /title/tt0243155/?ref_=adv_li_tt  (2001)    71500556
# 13   /title/tt0137523/?ref_=adv_li_tt  (1999)    37030102
# 553  /title/tt0117002/?ref_=adv_li_tt  (1996)     5600000

# %% [markdown]
# # 'Amazon Files' function: Using AmazonID, scrape Amazon pages.

# %%
page = 531
num = 531

for amzid in final_imdb['amazonid']:
    t0 = time.time()
    response_delay = time.time() - t0
    time.sleep(10*response_delay)  # wait 10x longer than it took them to respond
    
    website = 'https://www.amazon.com/exec/obidos/ASIN/%s/internetmoviedat/'
    url = website % amzid
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}
    soup =BeautifulSoup(requests.get(url, headers = header).text, "lxml")
 
    pretty_amazon = str(soup.prettify)
    pickle.dump(pretty_amazon, open("amazon_%s.p" % num, "wb"))
    
    print('Scraped page %d out of 606' % page)
    page += 1
    num += 1
# Out:
# Scraped page 1 out of 606
# Scraped page 2 out of 606
# Scraped page 3 out of 606
# Scraped page 4 out of 606
# Scraped page 5 out of 606
# Scraped page 6 out of 606
# Scraped page 7 out of 606
# Scraped page 8 out of 606
# Scraped page 9 out of 606
# Scraped page 10 out of 606
# Scraped page 11 out of 606
# Scraped page 12 out of 606
# Scraped page 13 out of 606
# Scraped page 14 out of 606
# Scraped page 15 out of 606
# Scraped page 16 out of 606
# Scraped page 17 out of 606
# Scraped page 18 out of 606
# Scraped page 19 out of 606
# Scraped page 20 out of 606
# Scraped page 21 out of 606
# Scraped page 22 out of 606
# Scraped page 23 out of 606
# Scraped page 24 out of 606
# Scraped page 25 out of 606
# Scraped page 26 out of 606
# Scraped page 27 out of 606
# Scraped page 28 out of 606
# Scraped page 29 out of 606
# Scraped page 30 out of 606
# Scraped page 31 out of 606
# Scraped page 32 out of 606
# Scraped page 33 out of 606
# Scraped page 34 out of 606
# Scraped page 35 out of 606
# Scraped page 36 out of 606
# Scraped page 37 out of 606
# Scraped page 38 out of 606
# Scraped page 39 out of 606
# Scraped page 40 out of 606
# Scraped page 41 out of 606
# Scraped page 42 out of 606
# Scraped page 43 out of 606
# Scraped page 44 out of 606
# Scraped page 45 out of 606
# Scraped page 46 out of 606
# Scraped page 47 out of 606
# Scraped page 48 out of 606
# Scraped page 49 out of 606
# Scraped page 50 out of 606
# Scraped page 51 out of 606
# Scraped page 52 out of 606
# Scraped page 53 out of 606
# Scraped page 54 out of 606
# Scraped page 55 out of 606
# Scraped page 56 out of 606
# Scraped page 57 out of 606
# Scraped page 58 out of 606
# Scraped page 59 out of 606
# Scraped page 60 out of 606
# Scraped page 61 out of 606
# Scraped page 62 out of 606
# Scraped page 63 out of 606
# Scraped page 64 out of 606
# Scraped page 65 out of 606
# Scraped page 66 out of 606
# Scraped page 67 out of 606
# Scraped page 68 out of 606
# Scraped page 69 out of 606
# Scraped page 70 out of 606
# Scraped page 71 out of 606
# Scraped page 72 out of 606
# Scraped page 73 out of 606
# Scraped page 74 out of 606
# Scraped page 75 out of 606
# Scraped page 76 out of 606
# Scraped page 77 out of 606
# Scraped page 78 out of 606
# Scraped page 79 out of 606
# Scraped page 80 out of 606
# Scraped page 81 out of 606
# Scraped page 82 out of 606
# Scraped page 83 out of 606
# Scraped page 84 out of 606
# Scraped page 85 out of 606
# Scraped page 86 out of 606
# Scraped page 87 out of 606
# Scraped page 88 out of 606
# Scraped page 89 out of 606
# Scraped page 90 out of 606
# Scraped page 91 out of 606
# Scraped page 92 out of 606
# Scraped page 93 out of 606
# Scraped page 94 out of 606
# Scraped page 95 out of 606
# Scraped page 96 out of 606
# Scraped page 97 out of 606
# Scraped page 98 out of 606
# Scraped page 99 out of 606
# Scraped page 100 out of 606
# Scraped page 101 out of 606
# Scraped page 102 out of 606
# Scraped page 103 out of 606
# Scraped page 104 out of 606
# Scraped page 105 out of 606
# Scraped page 106 out of 606
# Scraped page 107 out of 606
# Scraped page 108 out of 606
# Scraped page 109 out of 606
# Scraped page 110 out of 606
# Scraped page 111 out of 606
# Scraped page 112 out of 606
# Scraped page 113 out of 606
# Scraped page 114 out of 606
# Scraped page 115 out of 606
# Scraped page 116 out of 606
# Scraped page 117 out of 606
# Scraped page 118 out of 606
# Scraped page 119 out of 606
# Scraped page 120 out of 606
# Scraped page 121 out of 606
# Scraped page 122 out of 606
# Scraped page 123 out of 606
# Scraped page 124 out of 606
# Scraped page 125 out of 606
# Scraped page 126 out of 606
# Scraped page 127 out of 606
# Scraped page 128 out of 606
# Scraped page 129 out of 606
# Scraped page 130 out of 606
# Scraped page 131 out of 606
# Scraped page 132 out of 606
# Scraped page 133 out of 606
# Scraped page 134 out of 606
# Scraped page 135 out of 606
# Scraped page 136 out of 606
# Scraped page 137 out of 606
# Scraped page 138 out of 606
# Scraped page 577 out of 606
# Scraped page 578 out of 606
# Scraped page 579 out of 606
# Scraped page 580 out of 606
# Scraped page 581 out of 606
# Scraped page 582 out of 606
# Scraped page 583 out of 606
# Scraped page 584 out of 606
# Scraped page 585 out of 606
# Scraped page 586 out of 606
# Scraped page 587 out of 606
# Scraped page 588 out of 606
# Scraped page 589 out of 606
# Scraped page 590 out of 606
# Scraped page 591 out of 606
# Scraped page 592 out of 606
# Scraped page 593 out of 606
# Scraped page 594 out of 606
# Scraped page 595 out of 606
# Scraped page 596 out of 606
# Scraped page 597 out of 606
# Scraped page 598 out of 606
# Scraped page 599 out of 606
# Scraped page 600 out of 606
# Scraped page 601 out of 606
# Scraped page 602 out of 606
# Scraped page 603 out of 606
# Scraped page 604 out of 606
# Scraped page 605 out of 606
# Scraped page 606 out of 606

# %% [markdown]
# ## Find & remove 'Robot Check' files from 'Amazon' files

# %%
amazon_frame = pd.DataFrame()
amazon_frame['amazonid'] = final_imdb['amazonid']
amazon_frame['film'] = final_imdb['title']
amazon_frame['file_index'] = final_imdb.index

# %%
amazon_frame.head()
# Out:
#      amazonid                                     film  file_index
# 0  1338116738  Fantastic Beasts and Where to Find Them           0
# 1  1880909014                        Nocturnal Animals           1
# 2  1933662832                            The Godfather           2
# 3  1594633665                    The Girl on the Train           3
# 4  0964729237                                The Shack           4

# %%
def page_header(a, b):
    df = pd.DataFrame()
    header = []
    amazonid = []
    
    for number in range(a, b):
        soup = BeautifulSoup(pickle.load(open("amazon_%d.p" %number, "rb")), "lxml")        

        item1 = str(soup.find_all('title')[0].text)
        header.append(item1)    

    df['header'] = header

    return df

# %%
amazon_headers = page_header(1,607)

# %%
amazon_headers.head()
# Out:
#                                               header
# 0  The Beasts: Cinematic Guide (Fantastic Beasts ...
# 1  Tony and Susan: Austin Wright: 9781880909010: ...
# 2  The Godfather Classic Quotes: Carlo De Vito: 9...
# 3  The Girl on the Train: Paula Hawkins: 97808575...
# 4  The Shack: Where Tragedy Confronts Eternity: W...

# %%
amazon_frame['header'] = amazon_headers

# %%
final_imdb.loc[530:531]
# Out:
#         imdbid            gross  \
# 530  tt2217458  $43,838 (USA) (
# 531  tt0496319  $30,629 (USA) (
#
#                                                 amazon    amazonid  metascore  \
# 530  <a href="http://www.amazon.com/exec/obidos/ASI...  8532505945         44
# 531  <a href="http://www.amazon.com/exec/obidos/ASI...  0316540838         45
#
#       ranks              title                             links release  \
# 530  1,563.       Flores Raras  /title/tt2217458/?ref_=adv_li_tt  (2013)
# 531  1,571.  The Hottest State  /title/tt0496319/?ref_=adv_li_tt  (2006)
#
#      box_office
# 530       43838
# 531       30629

# %%
amazon_frame.loc[amazon_frame['header'] == 'Robot Check']
# Out:
#        amazonid                           film  file_index       header
# 531  0316540838              The Hottest State         531  Robot Check
# 534  0224050311                  Enduring Love         534  Robot Check
# 536  0747529396                Fugitive Pieces         536  Robot Check
# 539  2070371158              The Last Mistress         539  Robot Check
# 543  0152051600                     I Am David         543  Robot Check
# 546  0747267480                     Hallam Foe         546  Robot Check
# 550  1582341575                           P.S.         550  Robot Check
# 551  0345440188                The Ice Harvest         551  Robot Check
# 554  0747214670                            Red         554  Robot Check
# 555  0312134436                    Boy Culture         555  Robot Check
# 556  0989671488                        Big Sur         556  Robot Check
# 558  0446600253               Bless Me, Ultima         558  Robot Check
# 559  0670857459              Felicia's Journey         559  Robot Check
# 561  0385144520                    Let It Ride         561  Robot Check
# 562  0385485131            The Dancer Upstairs         562  Robot Check
# 565  0525941282                  The Statement         565  Robot Check
# 566  0709140118                       Palmetto         566  Robot Check
# 567  0684845040                  The Extra Man         567  Robot Check
# 568  0517799588                          Skins         568  Robot Check
# 570  0887846246           The Tracey Fragments         570  Robot Check
# 571  1841952974                 I'm Not Scared         571  Robot Check
# 573  0316171964       Night Falls on Manhattan         573  Robot Check
# 574  0394513843                         Tsotsi         574  Robot Check
# 575  0330345591                    Last Orders         575  Robot Check
# 577  0670887315                       Disgrace         577  Robot Check
# 578  0385498799                     Bee Season         578  Robot Check
# 579  077104707x                The Stone Angel         579  Robot Check
# 580  0743243307                     Brick Lane         580  Robot Check
# 581  090531011X           Brothers of the Head         581  Robot Check
# 582  0849943728                          Thr3e         582  Robot Check
# 584  1582430276            Breakfast with Scot         584  Robot Check
# 585  3499226138                  Gloomy Sunday         585  Robot Check
# 586  8721026335             Frygtelig lykkelig         586  Robot Check
# 587  8807016532                     Don't Tell         587  Robot Check
# 588  0842335706             The Last Sin Eater         588  Robot Check
# 589  2253119334                  Queen to Play         589  Robot Check
# 590  2290048763           Mademoiselle Chambon         590  Robot Check
# 591  3453124294            Nirgendwo in Afrika         591  Robot Check
# 593  2707315672              Les herbes folles         593  Robot Check
# 594  0151261008                Close Your Eyes         594  Robot Check
# 595  0517708620    Starting Out in the Evening         595  Robot Check
# 596  0151002878             The Little Traitor         596  Robot Check
# 597  043400622x  Love and Death on Long Island         597  Robot Check
# 598  0394558480   The Secret Lives of Dentists         598  Robot Check
# 600  0609610589        Blood Done Sign My Name         600  Robot Check
# 602  2070774627                   Unforgivable         602  Robot Check
# 603  0698106431         Prince of Central Park         603  Robot Check
# 604  0679422064                  The Treatment         604  Robot Check
# 605  0375411275                     Opal Dream         605  Robot Check

# %% [markdown]
# # 'Amazon' function: From Amazon files, get Amazon ID, Stars, Reviews, Ranks, Language, Publisher

# %%
def amazon_page(number):

    file_df = pd.DataFrame()

    amazonid = []
    title_author = []
    stars = []
    reviews = []
    bs_rank = []
    language = []
    publisher = []

    soup = BeautifulSoup(pickle.load(open("amazon_%d.p" % number, "rb")), "lxml")
    
    try:
        item1 = str(soup.find_all('title')[0].text).rpartition(
            ':')[0].rpartition(':')[0].rpartition(':')[0]
        title_author.append(item1)
    except: 
        title_author.append(np.nan)
        #Turns out the location of the title & author in the header is inconsistent.
    
    try:
        item2 = soup.find_all('span', {'class': 'reviewCountTextLinkedHistogram'})[0].get('title')
        stars.append(item2)
    except:
        stars.append(np.nan)
    
    try:
        item3 = soup.find_all('span', {'id': 'acrCustomerReviewText'})[0].text
        reviews.append(item3)
    except:
        reviews.append(np.nan)

    try:     
        item4 = soup.findAll(attrs={"id" : "amsDetailRightPBookTall"})[0].get('data-detailpageasin')
        amazonid.append(item4)
    except:
        amazonid.append(np.nan)
    
    try: 
        item5 = soup.find_all('li', {'id': 'SalesRank'})[0].find('span').text
        bs_rank.append(item5)    
    except:
        bs_rank.append(np.nan)

    try: 
        for child in soup.find_all('td', {'class' : 'bucket'})[0].find_all('li'):
            if "Language" in str(child.text):
                language.append(str(child.text))
    except:
        language.append(np.nan) 

    try: 
        for child in soup.find_all('td', {'class' : 'bucket'})[0].find_all('li'):
            if "Publisher" in str(child.text):
                publisher.append(str(child.text))
    except:
        publisher.append(np.nan) 
        
    del soup

    file_df['amazonid'] = amazonid
    file_df['title_author'] = title_author
    file_df['stars'] = stars
    file_df['reviews'] = reviews
    file_df['bs_rank'] = bs_rank
    file_df['language'] = language
    file_df['publisher'] = publisher
    
    
    return file_df

# %%
amazon_list = []

# %%
page = 1
for number in range (1, 531):
    df = amazon_page(int(number))
    header_list.append(df)
    print('Scraping file %d out of 530' % page)
    page +=1

# %%
len(amazon_list)

# %%
final_amazon = pd.concat(amazon_list)

# %%
final_amazon.shape
# Out:
# (516, 7)

# %%
pickle.dump(final_amazon, open("dirty_amazon.p", "wb"))

# %%
clean_amazon = final_amazon.dropna()

# %%
clean_amazon.shape
# Out:
# (460, 7)

# %% [markdown]
# ## 'Amazon' function: From Amazon files, rescrape header

# %%
# rescrape header without any rpartition.
def amazon_header(number):

    file_df = pd.DataFrame()

    amazonid = []
    header = []

    soup = BeautifulSoup(pickle.load(open("amazon_%d.p" % number, "rb")), "lxml")
    
    try:
        item1 = str(soup.find_all('title')[0].text)
        header.append(item1)
    except: 
        title_author.append(np.nan)
    
    try:     
        item4 = soup.findAll(attrs={"id" : "amsDetailRightPBookTall"})[0].get('data-detailpageasin')
        amazonid.append(item4)
    except:
        amazonid.append(np.nan)
    
    del soup

    file_df['amazonid'] = amazonid
    file_df['header'] = header
    
    
    return file_df

# %%
header_list = []

# %%
page = 1
for number in range (1, 531):
    df = amazon_header(int(number))
    header_list.append(df)
    print('Scraping file %d out of 530' % page)
    page +=1
#
# Out:
# Scraping file 1 out of 530
# Scraping file 2 out of 530
# Scraping file 3 out of 530
# Scraping file 4 out of 530
# Scraping file 5 out of 530
# Scraping file 6 out of 530
# Scraping file 7 out of 530
# Scraping file 8 out of 530
# Scraping file 9 out of 530
# Scraping file 10 out of 530
# Scraping file 11 out of 530
# Scraping file 12 out of 530
# Scraping file 13 out of 530
# Scraping file 14 out of 530
# Scraping file 15 out of 530
# Scraping file 16 out of 530
# Scraping file 17 out of 530
# Scraping file 18 out of 530
# Scraping file 19 out of 530
# Scraping file 20 out of 530
# Scraping file 21 out of 530
# Scraping file 22 out of 530
# Scraping file 23 out of 530
# Scraping file 24 out of 530
# Scraping file 25 out of 530
# Scraping file 26 out of 530
# Scraping file 27 out of 530
# Scraping file 28 out of 530
# Scraping file 29 out of 530
# Scraping file 468 out of 530
# Scraping file 469 out of 530
# Scraping file 470 out of 530
# Scraping file 471 out of 530
# Scraping file 472 out of 530
# Scraping file 473 out of 530
# Scraping file 474 out of 530
# Scraping file 475 out of 530
# Scraping file 476 out of 530
# Scraping file 477 out of 530
# Scraping file 478 out of 530
# Scraping file 479 out of 530
# Scraping file 480 out of 530
# Scraping file 481 out of 530
# Scraping file 482 out of 530
# Scraping file 483 out of 530
# Scraping file 484 out of 530
# Scraping file 485 out of 530
# Scraping file 486 out of 530
# Scraping file 487 out of 530
# Scraping file 488 out of 530
# Scraping file 489 out of 530
# Scraping file 490 out of 530
# Scraping file 491 out of 530
# Scraping file 492 out of 530
# Scraping file 493 out of 530
# Scraping file 494 out of 530
# Scraping file 495 out of 530
# Scraping file 496 out of 530
# Scraping file 497 out of 530
# Scraping file 498 out of 530
# Scraping file 499 out of 530
# Scraping file 500 out of 530
# Scraping file 501 out of 530
# Scraping file 502 out of 530
# Scraping file 503 out of 530
# Scraping file 504 out of 530
# Scraping file 505 out of 530
# Scraping file 506 out of 530
# Scraping file 507 out of 530
# Scraping file 508 out of 530
# Scraping file 509 out of 530
# Scraping file 510 out of 530
# Scraping file 511 out of 530
# Scraping file 512 out of 530
# Scraping file 513 out of 530
# Scraping file 514 out of 530
# Scraping file 515 out of 530
# Scraping file 516 out of 530
# Scraping file 517 out of 530
# Scraping file 518 out of 530
# Scraping file 519 out of 530
# Scraping file 520 out of 530
# Scraping file 521 out of 530
# Scraping file 522 out of 530
# Scraping file 523 out of 530
# Scraping file 524 out of 530
# Scraping file 525 out of 530
# Scraping file 526 out of 530
# Scraping file 527 out of 530
# Scraping file 528 out of 530
# Scraping file 529 out of 530
# Scraping file 530 out of 530

# %%
len(header_list)
# Out:
# 530

# %%
header_list[100]
# Out:
#      amazonid                                             header
# 0  038548948X  Amazon.com: Marie Antoinette: The Journey (978...

# %%
final_header = pd.concat(header_list)

# %%
final_header.sample(10)
# Out:
#      amazonid                                             header
# 0  0670865796  The Deep End of the Ocean: Jacquelyn Mitchard:...
# 0  0571224334  The Damned Utd: David Peace: 8601300335414: Am...
# 0  0446519723  Where the Heart is: Billie Letts: 978044651972...
# 0  0399136150  Amazon.com: The Sum of All Fears (978039913615...
# 0  9113015311  Luftslottet som Sprangdes: S Larsson: 97891130...
# 0         NaN  Amazon.com: Cosmopolis: A Novel (9780743244244...
# 0  0553071394  Amazon.com: Point of Impact (9780553071399): S...
# 0  0312315716  Little Children: A Novel: Tom Perrotta: 978031...
# 0  1573222127  Miracle at St. Anna: James McBride: 9781573222...
# 0  1847241697  Let the Right One in: John Ajvide Lindqvist: 9...

# %%
final_header = final_header.dropna()

# %%
final_header.shape
# Out:
# (503, 2)

# %%
pickle.dump(final_header, open("final_header.p", "wb"))

# %% [markdown]
# # Merge 'Amazon' df & 'clean header' df

# %%
cleanish_final = final_header.merge(clean_amazon, on='amazonid', how='left')

# %%
cleanish_final.sample(8)
# Out:
#        amazonid                                             header  \
# 88   1,555 customer reviews   #19095  Language: English
# 335    404 customer reviews    #6011  Language: English
# 253    101 customer reviews  #728725  Language: English
# 64                      NaN      NaN                NaN
#
#                                              publisher
# 102           Publisher: Boom! Studios (July 13, 2010)
# 88   Publisher: Scribner; First Edition edition (Ma...
# 335  Publisher: St. Martin's Press; First Edition e...
# 253         Publisher: Random House (January 13, 1995)
# 64                                                 NaN

# %%
clean_amazon.shape
# Out:
# (515, 8)

# %%
pd.isnull(clean_amazon.title_author).value_counts()
# Out:
# False    472
# True      43
# Name: title_author, dtype: int64

# %%
cleaner_amazon = clean_amazon.dropna(axis=0, how='any', subset= [
    'stars', 'reviews', 'bs_rank', 'language'], inplace=False)

# %%
cleaner_amazon.shape
# Out:
# (472, 8)

# %%
cleaner_amazon.sample(5)
# Out:
#        amazonid                                             header  \
# 47   0307346609  World War Z: An Oral History of the Zombie War...
# 340  0385335555  Tell No One: Harlan Coben: 9780385335553: Amaz...
# 241  1582346704  Nurse Matilda: The Collected Tales: Christiann...
# 413  1557046387  Vanity Fair: Bringing Thackeray's Timeless Nov...
# 136  0517542099  The Hitchhiker's Guide to the Galaxy: Douglas ...
#
#                                           title_author               stars  \
# 47   World War Z: An Oral History of the Zombie War...  4.3 out of 5 stars
# 340                          Tell No One: Harlan Coben  4.4 out of 5 stars
# 241  Nurse Matilda: The Collected Tales: Christiann...  4.1 out of 5 stars
# 413  Vanity Fair: Bringing Thackeray's Timeless Nov...  5.0 out of 5 stars
# 136  The Hitchhiker's Guide to the Galaxy: Douglas ...  4.5 out of 5 stars
#
#                     reviews bs_rank           language  \
# 47   5,392 customer reviews    #386  Language: English
# 340  1,315 customer reviews   #8433  Language: English
# 241     33 customer reviews   #4039  Language: English
# 413      3 customer reviews    #627  Language: English
# 136  5,139 customer reviews  #18203  Language: English
#
#                                              publisher
# 47   Publisher: Crown; 1st edition (September 12, 2...
# 340  Publisher: Delacorte Press; 1st edition (June ...
# 241  Publisher: Bloomsbury Children's Books; First ...
# 413  Publisher: Newmarket Press; 1St Edition editio...
# 136  Publisher: Harmony; 10th Anniversary ed editio...

# %%
cleaner_amazon.language.unique()
# Out:
# array(['Language: English'], dtype=object)

# %%
reviews = []
for s in cleaner_amazon['reviews']:
    s = re.sub("[^0-9]", "", s)
    reviews.append(s)
cleaner_amazon['reviews'] = reviews
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
ranks = []
for s in cleaner_amazon['bs_rank']:
    s = re.sub("[^0-9]", "", s)
    ranks.append(s)
cleaner_amazon['bs_rank'] = ranks
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
stars = []
for s in cleaner_amazon['stars']:
    s = s.replace(' out of 5 stars', '')
    stars.append(s)
cleaner_amazon['stars'] = stars
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
cleaner_amazon.stars.unique()
# Out:
# array(['5.0', '3.1', '4.7', '4.1', '3.9', '4.0', '4.6', '4.4', '4.8',
#        '4.3', '4.9', '3.6', '4.5', '3.8', '4.2', '3.4', '3.7', '2.9',
#        '3.5', '3.2', '2.8', '3.3'], dtype=object)

# %%
years = []
for s in cleaner_amazon['publisher']:
    s = re.sub("[^0-9]", "", s)[-4:]
    years.append(s)
cleaner_amazon['years'] = years
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
cleaner_amazon.years.unique()
# Out:
# array(['2016', '1993', '2007', '2015', '2012', '2001', '2011', '2010',
#        '2013', '1996', '2000', '1973', '1995', '1999', '1986', '1985',
#        '2005', '2014', '2008', '1963', '1983', '1998', '1978', '2003',
#        '2004', '2006', '1974', '2009', '1997', '1979', '1981', '1994',
#        '1991', '2002', '1989', '1987', '1990', '1992', '1988', '1980',
#        '1972', '1977', '1970', '1968', '1982', '1975', '1959', '1976',
#        '1969', '1971', '1984'], dtype=object)

# %% [markdown]
# ## Clean Publishers
# ### Smaller publishers

# %%
import re

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Publisher: ', '')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
cleaner_amazon['publisher'] = cleaner_amazon['publisher'].apply(lambda x: x.split('(')[0]).apply(lambda x: x.split(';')[0])
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.strip()
    s = s.replace('.', '').replace(',', '').replace(' and ', ' & ')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cleaner_amazon.sample(5)
# Out:
#        amazonid                                             header  \
# 198  0307341569  Amazon.com: Dark Places: A Novel (978030734156...
# 435  0764227378  Hadassah: One Night with the King: Tommy Tenne...
# 85   0765318741  I Am Legend: Richard Matheson: 2015765357151: ...
# 69   1845764226  Stardust: The Visual Companion: Stephen Jones,...
# 17   0151730857  The Princess Bride: S. Morgenstern's Classic T...
#
#                                           title_author stars reviews bs_rank  \
# 198                            Amazon.com: Dark Places   4.1    9286    5683
# 435  Hadassah: One Night with the King: Tommy Tenne...   4.5     187      37
# 85                       I Am Legend: Richard Matheson   4.3    1487    4620
# 69   Stardust: The Visual Companion: Stephen Jones,...   4.4      11     882
# 17   The Princess Bride: S. Morgenstern's Classic T...   4.4    2003   28469
#
#               language                 publisher years
# 198  Language: English                     Crown  2009
# 435  Language: English  Bethany House Publishers  2004
# 85   Language: English                 Tor Books  2007
# 69   Language: English               Titan Books  2007
# 17   Language: English                  Harcourt  1973

# %%
sorted(cleaner_amazon['publisher'].unique())
# Out:
# ['A Marian Wood Book/Putnam',
#  'Ace',
#  'Aegypan Books',
#  'Algonquin Books',
#  'Algonquin Books of Chapel Hill',
#  'Alma Publishing Company',
#  'Amulet Books',
#  'Anchor',
#  'Applause Theatre & Cinema Books',
#  'Atheneum',
#  'Atheneum Books for Young Readers',
#  'Atlantic Monthly Press',
#  'Atria',
#  'Atria Books',
#  'Back Bay Books',
#  'Ballantine Books',
#  'Bantam',
#  'Bantam Press',
#  'Bantam Spectra',
#  'Barnes & Noble Classics',
#  'Barnes&Noble Books',
#  'Baronet Books',
#  'Baskerville Publishers',
#  'Berkley',
#  'Bethany House Publishers',
#  'Bloomsbury',
#  "Bloomsbury Children's Books",
#  'Bloomsbury Publishing',
#  'Bloomsbury Publishing PLC',
#  'Bloomsbury USA',
#  'Bonanza Books',
#  'Bookthrift Co',
#  'Boom! Studios',
#  'Broadway',
#  'Broadway Books',
#  'Candlewick',
#  'Canongate Books',
#  'Carroll & Graf Pub',
#  'Chatto & Windus',
#  'Cider Mill Press',
#  'Citadel',
#  'Citadel Pr',
#  'City Lights Publishers',
#  'Counterpoint',
#  'CreateSpace Independent Publishing Platform',
#  'Crown',
#  'DK',
#  'David Fickling Books',
#  'Del Rey',
#  'Delacorte Books for Young Readers',
#  'Delacorte Press',
#  'Dell',
#  'Dell Publishing',
#  'Dell Trade Paperback',
#  'Disney Editions',
#  'Do-Not Press',
#  'Doubleday',
#  'Duckworth Publishing',
#  'Dufour Editions',
#  'Dutton',
#  'Dutton Adult',
#  'Dutton Books',
#  'E P Dutton',
#  'ECW Press',
#  'Ecco',
#  'Ember',
#  'Faber & Faber',
#  'Farrar Straus & Giroux',
#  'Fawcett',
#  'Flame',
#  'Flamingo',
#  'Forge',
#  'Forge Books',
#  'Franklin Watts',
#  'Frog Books',
#  'G P Putnam',
#  "G P Putnam's Sons",
#  "GP Putnam's Sons",
#  'Grand Central Publishing',
#  'Graywolf Press',
#  'GreenWilBk',
#  'Grove Press',
#  'Grove Weidenfeld',
#  'Hachette Books',
#  'Haikasoru',
#  'Hamish Hamilton Ltd',
#  'Harcourt',
#  'Harcourt Inc',
#  'Harmony',
#  'Harper',
#  'Harper Design',
#  'Harper Perennial',
#  'HarperCollins',
#  'HarperFestival',
#  'HarperTeen',
#  'HarperTorch',
#  'Harpercollins',
#  "Harpercollins Children's Books",
#  'Harvest Books',
#  'Henry Holt & Co',
#  'Hodder',
#  'Hodder & Stoughton',
#  "Hodder Children's Books",
#  'Houghton Mifflin',
#  'Houghton Mifflin Company',
#  'Houghton Mifflin Harcourt',
#  'Insight Editions',
#  'Island Books',
#  'It Books',
#  'Jonathan Cape',
#  'Jonathan Cape Ltd',
#  'Katherine Tegen Books',
#  'Knopf',
#  'Knopf Books for Young Readers',
#  'Little Brown',
#  'Little Brown & Co',
#  'Little Brown & Company',
#  'Little Brown Book Group',
#  'Little Brown Books for Young Readers',
#  'M Evans & Co',
#  'MTV Books',
#  'MacAdam/Cage',
#  'Main Street Books',
#  'Mammoth',
#  'Margaret K McElderry Books',
#  'Mariner Books',
#  'McGraw Hill',
#  'McGraw-Hill',
#  'Michael Joseph',
#  'Michael Joseph Ltd',
#  'Mysterious Press',
#  'Nan A Talese',
#  'Newmarket Press',
#  'Onyx',
#  'Other Press',
#  'Oxford University Press',
#  'PROFILE BOOKS',
#  'Pamela Dorman Books',
#  'Penguin Books',
#  'Penguin Books Ltd',
#  'Penguin Classic',
#  'Penguin Classics',
#  'Penguin Press HC The',
#  'Penguin Putnam~childrens Hc',
#  'Persephone Books',
#  'Phoenix Pick',
#  'Picador',
#  'Playboy Press : trade distribution by Simon & Schuster',
#  'Pocket',
#  'Pocket Books',
#  'Pocket Star',
#  'Poisoned Pen Press',
#  'Prentice Hall',
#  'Puffin Books',
#  'Putnam',
#  'Putnam Adult',
#  'Quercus',
#  'Quirk Books',
#  'Random House',
#  'Random House Books for Young Readers',
#  'Random House Value Publishing',
#  'Red Fox',
#  'Renaissance Books',
#  'Riverhead Books',
#  'Riverhead Hardcover',
#  'Roc',
#  'Rugged Land',
#  'Running Press',
#  'SIMON & SCHUSTER LTD',
#  'Samuel French Ltd',
#  'Saturday Review Press',
#  'Sceptre',
#  'Scholastic',
#  'Scholastic Inc',
#  'Scholastic Paperbacks',
#  'Scholastic Press',
#  'Scribner',
#  "Serpent's Tail",
#  'Signet',
#  'Signet Classics',
#  'Simon & Schuster',
#  'Simon Pulse',
#  'Soho Press',
#  'Spectra',
#  "St Martin's Griffin",
#  "St Martin's Paperbacks",
#  "St Martin's Press",
#  'St Martins Pr',
#  'The Dial Press',
#  'Thomas Dunne Books',
#  'Three Rivers Press',
#  'Titan Books',
#  'TokyoPop',
#  'Top Shelf Productions',
#  'Tor Books',
#  'Touchstone',
#  'Transworld Publishers',
#  'Turtleback Books',
#  'Univ Of Minnesota Press',
#  'University Of Chicago Press',
#  'University of California Press',
#  'Victor Gollancz',
#  'Viking',
#  'Viking Adult',
#  'Viking Books for Young Readers',
#  'Villard',
#  'Vintage',
#  'Vintage / Random House',
#  'Vintage Crime/Black Lizard',
#  'Virago',
#  'W W Norton',
#  'W W Norton & Company',
#  'Walker & Co',
#  'Warner',
#  'Warner Books',
#  'Washington Square Press',
#  'Watermark Press',
#  'Weidenfeld & Nicolson',
#  'William Morrow',
#  'William Morrow & Co',
#  'Windblown Media',
#  'Yearling',
#  'Zoland Books',
#  'distributed by Houghton Mifflin',
#  'iUniverse Inc']

# %%
cleaner_amazon['publisher'].value_counts()
# Out:
# Knopf                            28
# Doubleday                        15
# Random House                     13
# Signet                           10
# Scribner                         10
# St Martin's Press                 9
# Little Brown & Company            8
# Newmarket Press                   8
# Simon & Schuster                  8
# Warner Books                      7
# Delacorte Press                   7
# Ballantine Books                  6
# G P Putnam's Sons                 6
# Grand Central Publishing          6
# Viking Adult                      6
# Farrar Straus & Giroux            6
# Crown                             5
# Atlantic Monthly Press            5
# Viking                            5
# Knopf Books for Young Readers     5
# Scholastic Press                  5
# Renaissance Books                 4
# Riverhead Books                   4
# Bloomsbury Publishing PLC         4
# Bantam                            4
# Berkley                           4
# Pocket                            4
# William Morrow & Co               4
# Little Brown                      4
# Houghton Mifflin Harcourt         3
#                                  ..
# Harcourt Inc                      1
# Bloomsbury USA                    1
# Hamish Hamilton Ltd               1
# Onyx                              1
# Dell                              1
# Penguin Classic                   1
# Riverhead Hardcover               1
# Bonanza Books                     1
# Bookthrift Co                     1
# Grove Weidenfeld                  1
# Michael Joseph                    1
# MTV Books                         1
# E P Dutton                        1
# Graywolf Press                    1
# Barnes&Noble Books                1
# Hodder & Stoughton                1
# G P Putnam                        1
# Flame                             1
# Zoland Books                      1
# Sceptre                           1
# SIMON & SCHUSTER LTD              1
# Thomas Dunne Books                1
# TokyoPop                          1
# Red Fox                           1
# Weidenfeld & Nicolson             1
# Virago                            1
# Phoenix Pick                      1
# Quercus                           1
# McGraw-Hill                       1
# Scholastic Inc                    1
# Name: publisher, dtype: int64

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Bantam Press', 'Bantam').replace('Bantam Spectra', 'Bantam')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace("G P Putnam's Sons", 'G P Putnam').replace(
        "GP Putnam's Sons", 'G P Putnam').replace(
        'Putnam Adult', 'G P Putnam').replace(
        'Putnam', 'G P Putnam').replace(
        'G P G P Putnam', 'G P Putnam')
     
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Bloomsbury Children\'s Books', 'Bloomsbury').replace(
        'Bloomsbury Publishing', 'Bloomsbury').replace(
        'Bloomsbury Publishing PLC', 'Bloomsbury').replace(
        'Bloomsbury USA', 'Bloomsbury').replace('Bloomsbury PLC', 'Bloomsbury')
    
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Dutton Adult', 'Dutton').replace('Dutton Books', 'Dutton')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Delacorte Books for Young Readers', 'Delacorte Press')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Scholastic Inc', 'Scholastic').replace(
        'Scholastic Paperbacks', 'Scholastic').replace('Scholastic Press', 'Scholastic')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Houghton Mifflin Company', 'Houghton Mifflin').replace(
        'Houghton Mifflin Harcourt', 'Houghton Mifflin')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Signet Classics', 'Signet')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
publisher = []
for s in cleaner_amazon['publisher']:
    s = s.replace('Viking Adult', 'Viking').replace(
        'Viking Books for Young Readers', 'Viking')
    publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Big5 Publisher: Simon and Schuster's publishing divisions and imprints include Atria, Folger Shakespeare Library, Free Press, Gallery Books, Howard Books, Pocket Books, Scribner, Simon & Schuster, Threshold Editions and Touchstone.

# %%
publisher = []
big_five = ['SIMON & SCHUSTER LTD', 'Atria', 'Atria Books', 'Pocket', 'Pocket Books', 
            'Pocket Star', 'Scribner', 'Touchstone', 
            'Playboy Press : trade distribution by Simon & Schuster']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        s = s.replace(s, 'Simon & Schuster')
        publisher.append(s)
    else:
        publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Big5 Publisher: As a result, Penguin Random House has nearly 250 imprints and publishing houses. Some of the most well-known Penguin Random House publishing groups are: Random House Publishing Group, Knopf Doubleday Publishing Group; Crown Publishing Group; Penguin Group U.S.; Dorling Kindersley; Mass Market Paperbacks, Penguin Group U.S.; Random House Children's Books; Penguin Young Readers Group, U.S.

# %%
publisher = []
big_five = ['Penguin Books Ltd', 'Penguin Classic', 'Penguin Classics', 'Penguin Press HC The', 
           'Penguin Putnam~childrens Hc', 'Random House Books for Young Readers', 
           'Random House Value Publishing', 'Alfred A Knopf', 'Knopf', 'Random House',
            'Knopf Books for Young Readers', 'Doubleday','Crown','Penguin Bookss', 'Penguin Books']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        s = s.replace(s, 'Penguin Random House')
        publisher.append(s)
    else:
        publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %% [markdown]
# ### Big5 Publisher: Hachette's publishing divisions include Grand Central Publishing; Little, Brown and Company; Little, Brown and Company Books for Young Readers; Faith Words; Center Street; Orbit; Yen Press; Hachette Audio; and Hachette Digital. Read about Forever, Hachette's Romance line, and about Forever Yours, their digital first Romance line. Time Warner acquired Little, Brown in 1968 and HBG was created when Hachette Livre acquired Time Warner Book Group in 2006.

# %%
publisher = []
big_five = ['Little Brown & Co', 'Little Brown', 'Little Brown & Company', 'Little Brownmpany',
            'Warner Books', 'Warner',
            'Little Brown Book Group', 'Little Brown Books for Young Readers', 
            'Grand Central Publishing',]
for s in cleaner_amazon['publisher']:
    if s in big_five:
        s = s.replace(s, 'Hachette Books')
        publisher.append(s)
    else:
        publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %% [markdown]
# ### Big5 Publisher: Some of HarperCollins publishers and imprints are: HaperCollins; William Morrow; Avon Books; Broadside Books; Harper Business; HarperCollinsChildrens; HarperTeen; Ecco Books; It Books; Newmarket Press; Harper One; Harper Voyager US; Harper Perennial; HarperAcademic and Harper Audio.

# %%
publisher = []
big_five = ['HarperCollins', 'HarperCollins Design', 'HarperCollins Perennial', 
            'HarperCollinsCollins', 'HarperCollinsFestival', 'HarperCollinsTeen', 'HarperCollinsTorch', 
            'HarperCollinscollins', "HarperCollinscollins Children's Books", 'William Morrow & Co', 
            'William Morrow', 'Ecco', 'It Books']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        s = s.replace(s, 'HarperCollins')
        publisher.append(s)
    else:
        publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %% [markdown]
# ### Big5 Publisher: The Macmillan U.S. trade book publishers include Farrar, Straus and Giroux; Henry Holt and Company; Picador; St. Martin’s Press; Tor/Forge; Macmillan Audio; and Macmillan Children’s Publishing Group. Macmillan also publishes into the college and academic book marketplace. In the many of the Macmillan U.S. publishers headquartered in New York City's historic Flatiron Building.
# https://www.thebalance.com/the-big-five-trade-book-publishers-2800047
# Updated April 24, 2017

# %%
publisher = []
big_five = ["St Martin's Griffin", "St Martin's Paperbacks", 'St Martins Pr', "St Martin's Press", 
            'Farrar Straus & Giroux', 'Henry Holt & Co', 'Picador', 'Tor Books','Forge',
            'Forge Books']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        s = s.replace(s, "Macmillan")
        publisher.append(s)
    else:
        publisher.append(s)
cleaner_amazon['publisher'] = publisher
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
sorted(cleaner_amazon['publisher'].unique())
# Out:
# ['A Marian Wood Book/G P Putnam',
#  'Ace',
#  'Aegypan Books',
#  'Algonquin Books',
#  'Algonquin Books of Chapel Hill',
#  'Alma Publishing Company',
#  'Amulet Books',
#  'Anchor',
#  'Applause Theatre & Cinema Books',
#  'Atheneum',
#  'Atheneum Books for Young Readers',
#  'Atlantic Monthly Press',
#  'Back Bay Books',
#  'Ballantine Books',
#  'Bantam',
#  'Barnes & Noble Classics',
#  'Barnes&Noble Books',
#  'Baronet Books',
#  'Baskerville Publishers',
#  'Berkley',
#  'Bethany House Publishers',
#  'Bloomsbury',
#  'Bonanza Books',
#  'Bookthrift Co',
#  'Boom! Studios',
#  'Broadway',
#  'Broadway Books',
#  'Candlewick',
#  'Canongate Books',
#  'Carroll & Graf Pub',
#  'Chatto & Windus',
#  'Cider Mill Press',
#  'Citadel',
#  'Citadel Pr',
#  'City Lights Publishers',
#  'Counterpoint',
#  'CreateSpace Independent Publishing Platform',
#  'DK',
#  'David Fickling Books',
#  'Del Rey',
#  'Delacorte Press',
#  'Dell',
#  'Dell Publishing',
#  'Dell Trade Paperback',
#  'Disney Editions',
#  'Do-Not Press',
#  'Duckworth Publishing',
#  'Dufour Editions',
#  'Dutton',
#  'E P Dutton',
#  'ECW Press',
#  'Ember',
#  'Faber & Faber',
#  'Fawcett',
#  'Flame',
#  'Flamingo',
#  'Franklin Watts',
#  'Frog Books',
#  'G P G P Putnam',
#  'G P Putnam',
#  'Graywolf Press',
#  'GreenWilBk',
#  'Grove Press',
#  'Grove Weidenfeld',
#  'Hachette Books',
#  'Haikasoru',
#  'Hamish Hamilton Ltd',
#  'Harcourt',
#  'Harcourt Inc',
#  'Harmony',
#  'HarperCollins',
#  'Harvest Books',
#  'Hodder',
#  'Hodder & Stoughton',
#  "Hodder Children's Books",
#  'Houghton Mifflin',
#  'Insight Editions',
#  'Island Books',
#  'Jonathan Cape',
#  'Jonathan Cape Ltd',
#  'Katherine Tegen Books',
#  'M Evans & Co',
#  'MTV Books',
#  'MacAdam/Cage',
#  'Macmillan',
#  'Main Street Books',
#  'Mammoth',
#  'Margaret K McElderry Books',
#  'Mariner Books',
#  'McGraw Hill',
#  'McGraw-Hill',
#  'Michael Joseph',
#  'Michael Joseph Ltd',
#  'Mysterious Press',
#  'Nan A Talese',
#  'Newmarket Press',
#  'Onyx',
#  'Other Press',
#  'Oxford University Press',
#  'PROFILE BOOKS',
#  'Pamela Dorman Books',
#  'Penguin Random House',
#  'Persephone Books',
#  'Phoenix Pick',
#  'Poisoned Pen Press',
#  'Prentice Hall',
#  'Puffin Books',
#  'Quercus',
#  'Quirk Books',
#  'Red Fox',
#  'Renaissance Books',
#  'Riverhead Books',
#  'Riverhead Hardcover',
#  'Roc',
#  'Rugged Land',
#  'Running Press',
#  'Samuel French Ltd',
#  'Saturday Review Press',
#  'Sceptre',
#  'Scholastic',
#  "Serpent's Tail",
#  'Signet',
#  'Simon & Schuster',
#  'Simon Pulse',
#  'Soho Press',
#  'Spectra',
#  'The Dial Press',
#  'Thomas Dunne Books',
#  'Three Rivers Press',
#  'Titan Books',
#  'TokyoPop',
#  'Top Shelf Productions',
#  'Transworld Publishers',
#  'Turtleback Books',
#  'Univ Of Minnesota Press',
#  'University Of Chicago Press',
#  'University of California Press',
#  'Victor Gollancz',
#  'Viking',
#  'Villard',
#  'Vintage',
#  'Vintage / Random House',
#  'Vintage Crime/Black Lizard',
#  'Virago',
#  'W W Norton',
#  'W W Norton & Company',
#  'Walker & Co',
#  'Washington Square Press',
#  'Watermark Press',
#  'Weidenfeld & Nicolson',
#  'Windblown Media',
#  'Yearling',
#  'Zoland Books',
#  'distributed by Houghton Mifflin',
#  'iUniverse Inc']

# %%
cleaner_amazon['publisher'].value_counts()
# Out:
# Penguin Random House           77
# Simon & Schuster               33
# Hachette Books                 33
# HarperCollins                  29
# Macmillan                      28
# Viking                         12
# G P G P Putnam                 12
# Signet                         11
# Bloomsbury                     10
# Scholastic                      9
# Newmarket Press                 8
# Delacorte Press                 8
# Houghton Mifflin                7
# Bantam                          6
# Ballantine Books                6
# Atlantic Monthly Press          5
# Dutton                          5
# Riverhead Books                 4
# Renaissance Books               4
# Berkley                         4
# Faber & Faber                   3
# Amulet Books                    3
# Mysterious Press                3
# Villard                         3
# Katherine Tegen Books           3
# Candlewick                      3
# Harcourt                        3
# Fawcett                         3
# MacAdam/Cage                    3
# W W Norton & Company            3
#                                ..
# Carroll & Graf Pub              1
# Flamingo                        1
# University Of Chicago Press     1
# Frog Books                      1
# McGraw-Hill                     1
# David Fickling Books            1
# iUniverse Inc                   1
# Broadway                        1
# Do-Not Press                    1
# TokyoPop                        1
# Baskerville Publishers          1
# Walker & Co                     1
# Hamish Hamilton Ltd             1
# McGraw Hill                     1
# MTV Books                       1
# Spectra                         1
# Puffin Books                    1
# Cider Mill Press                1
# Michael Joseph Ltd              1
# Prentice Hall                   1
# Boom! Studios                   1
# Harcourt Inc                    1
# Red Fox                         1
# Persephone Books                1
# Bookthrift Co                   1
# Barnes & Noble Classics         1
# Riverhead Hardcover             1
# Hodder                          1
# Onyx                            1
# Bonanza Books                   1
# Name: publisher, dtype: int64

# %%
big_publishing = []
big_five = ['Penguin Random House', 'Hachette Books', 'Simon & Schuster', 
                  'HarperCollins', 'Macmillan']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        big_publishing.append(1)
    else:
        big_publishing.append(0)
cleaner_amazon['big_publishing'] = big_publishing
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
cleaner_amazon.sample(5)
# Out:
#        amazonid                                             header  \
# 451  0743482700  Exorcist: The Beginning: Steven Piziks, Alexi ...
# 56   0439064864  Harry Potter and the Chamber of Secrets: J.K. ...
# 126  0446525537  A Walk to Remember: Nicholas Sparks: 978044652...
# 310  1565124995  Water for Elephants: A Novel: Sara Gruen: 9781...
# 466  0451201078  Leonard Maltin's Movie and Video Guide 2001 (L...
#
#                                           title_author stars reviews bs_rank  \
# 451  Exorcist: The Beginning: Steven Piziks, Alexi ...   3.2       6    8557
# 56   Harry Potter and the Chamber of Secrets: J.K. ...   4.7   12596      10
# 126                A Walk to Remember: Nicholas Sparks   4.5    2141    1070
# 310           Water for Elephants: A Novel: Sara Gruen   4.5    7517     718
# 466  Leonard Maltin's Movie and Video Guide 2001 (L...   3.9     478    3450
#
#               language                       publisher years  big_publishing
# 451  Language: English                Simon & Schuster  2004               1
# 56   Language: English                      Scholastic  1999               0
# 126  Language: English                  Hachette Books  1999               1
# 310  Language: English  Algonquin Books of Chapel Hill  2006               0
# 466  Language: English                          Signet  2000               0

# %% [markdown]
# # Dummy Publishers

# %%
PRH_dummy = []
big_five = ['Penguin Random House']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        PRH_dummy.append(1)
    else:
        PRH_dummy.append(0)
cleaner_amazon['PRH_dummy'] = PRH_dummy

# %%
H_Books_dummy = []
big_five = ['Hachette Books']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        H_Books_dummy.append(1)
    else:
        H_Books_dummy.append(0)
cleaner_amazon['H_Books_dummy'] = H_Books_dummy

# %%
SS_dummy = []
big_five = ['Simon & Schuster']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        SS_dummy.append(1)
    else:
        SS_dummy.append(0)
cleaner_amazon['SS_dummy'] = SS_dummy

# %%
HC_dummy = []
big_five = ['HarperCollins']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        HC_dummy.append(1)
    else:
        HC_dummy.append(0)
cleaner_amazon['HC_dummy'] = HC_dummy

# %%
Mac_dummy = []
big_five = ['Macmillan']
for s in cleaner_amazon['publisher']:
    if s in big_five:
        Mac_dummy.append(1)
    else:
        Mac_dummy.append(0)
cleaner_amazon['Mac_dummy'] = Mac_dummy

# %%
cleaner_amazon.sample(5)
# Out:
#        amazonid                                             header  \
# 130  0385751060  Amazon.com: The Boy in the Striped Pajamas (97...
# 217  0316160202  Eclipse (Twilight): Stephenie Meyer: 978031616...
# 469  0375400370  Evening: Susan Minot: 9780375400377: Amazon.co...
# 485  1555973221  Loverboy: Victoria Redel: 9781555973223: Amazo...
# 138  0061774154  Fifth Avenue, 5 A.M.: Audrey Hepburn, Breakfas...
#
#                                           title_author stars reviews bs_rank  \
# 130                                         Amazon.com   4.6    1641      22
# 217                Eclipse (Twilight): Stephenie Meyer   4.6    3208      92
# 469                               Evening: Susan Minot   3.4     149   84172
# 485                           Loverboy: Victoria Redel   4.2      27   18468
# 138  Fifth Avenue, 5 A.M.: Audrey Hepburn, Breakfas...   4.0     146     497
#
#               language             publisher years  big_publishing  PRH_dummy  \
# 130  Language: English  David Fickling Books  2006               0          0
# 217  Language: English        Hachette Books  2007               1          0
# 469  Language: English  Penguin Random House  1998               1          1
# 485  Language: English        Graywolf Press  2001               0          0
# 138  Language: English         HarperCollins  2010               1          0
#
#      H_Books_dummy  SS_dummy  HC_dummy  Mac_dummy
# 130              0         0         0          0
# 217              1         0         0          0
# 469              0         0         0          0
# 485              0         0         0          0
# 138              0         0         1          0

# %%
pickle.dump(cleaner_amazon, open("cleaner_amazon.p", "wb"))
